# %% [markdown]
# <a href="https://colab.research.google.com/github/Rukawuba/4GeeksAcademy/blob/master/Madrid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib

# %%
ds = pd.read_csv('idealista_madrid.csv', sep=',')
pd.set_option('display.max_columns', None)  # Set to None to display all columns
ds
# Out:
#                                                url  \
# 0    https://www.idealista.com/inmueble/104027174/
# 1    https://www.idealista.com/inmueble/102321942/
# 2    https://www.idealista.com/inmueble/103334142/
# 3    https://www.idealista.com/inmueble/104161987/
# 4    https://www.idealista.com/inmueble/103989666/
# ..                                             ...
# 910  https://www.idealista.com/inmueble/103960809/
# 911  https://www.idealista.com/inmueble/103494183/
# 912  https://www.idealista.com/inmueble/102107584/
# 913   https://www.idealista.com/inmueble/99991709/
# 914  https://www.idealista.com/inmueble/103315777/
#
#                                             listingUrl  \
# 0    https://www.idealista.com/venta-viviendas/madr...
# 1    https://www.idealista.com/venta-viviendas/madr...
# 2    https://www.idealista.com/venta-viviendas/madr...
# 3    https://www.idealista.com/venta-viviendas/madr...
# 4    https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   url                         915 non-null    object
#  1   listingUrl                  915 non-null    object
#  2   title                       915 non-null    object
#  3   id                          915 non-null    int64
#  4   price                       915 non-null    int64
#  5   baths                       915 non-null    int64
#  6   rooms                       915 non-null    int64
#  7   sqft                        915 non-null    int64
#  8   description                 914 non-null    object
#  9   address                     915 non-null    object
#  10  typology                    915 non-null    object
#  11  advertiserProfessionalName  915 non-null    object
#  12  advertiserName              915 non-null    object
# ...

# %%
#ds.shape = 915, 13
ds.describe()
# Out:
#                  id         price       baths       rooms         sqft
# count  9.150000e+02  9.150000e+02  915.000000  915.000000   915.000000
# mean   1.020578e+08  1.290575e+06    2.900546    3.474317   217.238251
# std    5.338810e+06  1.036640e+06    1.626487    1.594625   191.745826
# min    2.547319e+07  1.220000e+05    1.000000    0.000000    14.000000
# 25%    1.019509e+08  6.250000e+05    2.000000    2.000000   104.000000
# 50%    1.031510e+08  9.900000e+05    3.000000    3.000000   158.000000
# 75%    1.037703e+08  1.650000e+06    4.000000    4.000000   264.000000
# max    1.042055e+08  8.900000e+06   12.000000   12.000000  1768.000000

# %%
import pandas as pd

# Assuming your data is in a pandas dataframe called 'data'
min_row = ds.iloc[ds['price'].idxmin()]


print("Row with cheapest house price:")
print(min_row)


import pandas as pd

# Assuming your DataFrame is called 'df' and the price column is named 'price'
max_price_index = ds['price'].argmax()
# Get the index of the row with the highest price

# Access the entire row using the index
highest_price_row = ds.iloc[max_price_index]
print("Row with most expensive house price:")
print(highest_price_row)
# Out:
# Row with cheapest house price:
# url                               https://www.idealista.com/inmueble/103920884/
# listingUrl                    https://www.idealista.com/venta-viviendas/madr...
# title                                         Piso en venta en calle de Zabalza
# id                                                                    103920884
# price                                                                    122000
# baths                                                                         1
# rooms                                                                         2
# sqft                                                                         48
# description                   Vivienda de 48 m² formado por salón comedor de...
# address                                                        Simancas, Madrid
# typology                                                                  Pisos
# ...

# %%
#Dropping Unnecessary columns...

ds.drop(["description", "advertiserProfessionalName"], axis = 1, inplace = True)
ds.head()
# Out:
#                                              url  \
# 0  https://www.idealista.com/inmueble/104027174/
# 1  https://www.idealista.com/inmueble/102321942/
# 2  https://www.idealista.com/inmueble/103334142/
# 3  https://www.idealista.com/inmueble/104161987/
# 4  https://www.idealista.com/inmueble/103989666/
#
#                                           listingUrl  \
# 0  https://www.idealista.com/venta-viviendas/madr...
# 1  https://www.idealista.com/venta-viviendas/madr...
# 2  https://www.idealista.com/venta-viviendas/madr...
# 3  https://www.idealista.com/venta-viviendas/madr...
# 4  https://www.idealista.com/venta-viviendas/madr...
#
#                                        title         id    price  baths  \
# 0       Piso en venta en calle de Villanueva  104027174  1920000      3
# 1  Piso en venta en calle de Núñez de Balboa  102321942  1995000      3
# 2       Piso en venta en Conde Orgaz-Piovera  103334142  1300000      3
# ...

# %%
'''
01. Which is the most expensive house in the dataset? (★☆☆)
'''
#index of the row with the highest price
max_price_index = ds['price'].argmax()

# Access the entire row using the index
highest_price_row = ds.iloc[max_price_index]

print(highest_price_row)
#The house with the id 100208717 and is the most expensive 8,900,000 euros.
# Out:
# url                   https://www.idealista.com/inmueble/100208717/
# listingUrl        https://www.idealista.com/venta-viviendas/madr...
# title                                      Piso en venta en Serrano
# id                                                        100208717
# price                                                       8900000
# baths                                                             6
# rooms                                                             5
# sqft                                                            713
# address                                           Recoletos, Madrid
# typology                                                      Pisos
# advertiserName                            álvora capital properties
# Name: 494, dtype: object

# %%
'''
02. Which is the cheapest house in the dataset? (★☆☆)
'''

min_price_index = ds['price'].argmin()
min_price_row = ds.iloc[min_price_index]

print(min_price_row)
#THe house with the id #103920884 has the lowest price at 122,000 euros.
# Out:
# url                   https://www.idealista.com/inmueble/103920884/
# listingUrl        https://www.idealista.com/venta-viviendas/madr...
# title                             Piso en venta en calle de Zabalza
# id                                                        103920884
# price                                                        122000
# baths                                                             1
# rooms                                                             2
# sqft                                                             48
# address                                            Simancas, Madrid
# typology                                                      Pisos
# advertiserName                                          Tengotucasa
# Name: 741, dtype: object

# %%
'''
# TODO
Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
Print both the address and the surface of the selected houses. For example:

The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters

The smaller house is located on County Road 1 N and its surface is 200 meters
'''

max_sqft_size_index = ds['sqft'].argmax()
max_sqft_size_row = ds.iloc[max_sqft_size_index]
print(max_sqft_size_row)
#The house id with 103628504 with the most square feet is 1768 square

min_sqft_size_index = ds['sqft'].argmin()
min_sqft_size_row = ds.iloc[min_sqft_size_index]

print(min_sqft_size_row)
#The house id with 103869856 with the smallest square feet is 14 square
# Out:
# url                   https://www.idealista.com/inmueble/103628504/
# listingUrl        https://www.idealista.com/venta-viviendas/madr...
# title             Casa o chalet independiente en venta en El Pla...
# id                                                        103628504
# price                                                       2900000
# baths                                                            12
# rooms                                                             7
# sqft                                                           1768
# address                                             Moncloa, Madrid
# typology                                             Independientes
# advertiserName                                      Promora Aravaca
# Name: 788, dtype: object
# url                   https://www.idealista.com/inmueble/103869856/
# listingUrl        https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             915 non-null    object
#  1   listingUrl      915 non-null    object
#  2   title           915 non-null    object
#  3   id              915 non-null    int64
#  4   price           915 non-null    int64
#  5   baths           915 non-null    int64
#  6   rooms           915 non-null    int64
#  7   sqft            915 non-null    int64
#  8   address         915 non-null    object
#  9   typology        915 non-null    object
#  10  advertiserName  915 non-null    object
# dtypes: int64(5), object(6)
# memory usage: 78.8+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Assuming 'price' is the column containing prices in your DataFrame
prices_millions = ds['price'] / 1000000  # Convert prices to millions

# Plot the histogram
plt.hist(prices_millions, bins=30, color='blue', edgecolor='black')

# Add labels and title
plt.xlabel('Price (Millions)')
plt.ylabel('Frequency')
plt.title('Histogram of Prices')

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Assuming 'price' is the column containing prices in your DataFrame
bathrooms = ds['baths'] # Convert prices to millions

# Plot the histogram
plt.hist(bathrooms, bins=30, color='red', edgecolor='black')

# Add labels and title
plt.xlabel('Bathrooms')
plt.ylabel('Frequency')
plt.title('Bathrooms count')

# Show plot
plt.show()

# %%
# Assuming 'price' is the column containing prices in your DataFrame
rooms = ds['rooms'] # Convert prices to millions

# Plot the histogram
plt.hist(rooms, bins=40, color='blue', edgecolor='black')

# Add labels and title
plt.xlabel('rooms')
plt.ylabel('Frequency')
plt.title('rooms')

# Show plot
plt.show()

# %%
style = ds['typology']
#plot the histogram
plt.hist(style,bins=2, color='red', edgecolor='black')

#adding labels
plt.xlabel('style')
plt.ylabel('frequency')
plt.title('House Style')

plt.show()

# %%
ds['advertiserName'].nunique()
# Out:
# 118

# %%
ds
# Out:
#                                                url  \
# 0    https://www.idealista.com/inmueble/104027174/
# 1    https://www.idealista.com/inmueble/102321942/
# 2    https://www.idealista.com/inmueble/103334142/
# 3    https://www.idealista.com/inmueble/104161987/
# 4    https://www.idealista.com/inmueble/103989666/
# ..                                             ...
# 910  https://www.idealista.com/inmueble/103960809/
# 911  https://www.idealista.com/inmueble/103494183/
# 912  https://www.idealista.com/inmueble/102107584/
# 913   https://www.idealista.com/inmueble/99991709/
# 914  https://www.idealista.com/inmueble/103315777/
#
#                                             listingUrl  \
# 0    https://www.idealista.com/venta-viviendas/madr...
# 1    https://www.idealista.com/venta-viviendas/madr...
# 2    https://www.idealista.com/venta-viviendas/madr...
# 3    https://www.idealista.com/venta-viviendas/madr...
# 4    https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
import pandas as pd

# List all unique values in the "address" column
unique_addresses = ds['address'].unique()
print(unique_addresses)
#All of the unique addresses in Madrid
# Out:
# ['Recoletos, Madrid' 'Castellana, Madrid' 'Hortaleza, Madrid'
#  'Chamartín, Madrid' 'Cuatro Caminos, Madrid' 'Goya, Madrid'
#  'Aravaca, Madrid' 'Sol, Madrid' 'Bernabéu-Hispanoamérica, Madrid'
#  'Vallehermoso, Madrid' 'Huertas-Cortes, Madrid' 'Chamberí, Madrid'
#  'Nueva España, Madrid' 'Conde Orgaz-Piovera, Madrid'
#  'Chueca-Justicia, Madrid' 'Argüelles, Madrid'
#  'Nuevos Ministerios-Ríos Rosas, Madrid' 'Centro, Madrid'
#  'Moncloa, Madrid' 'Retiro, Madrid' 'Barrio de Salamanca, Madrid'
#  'Peñagrande, Madrid' 'Mirasierra, Madrid' 'Fuencarral, Madrid'
#  'Comillas, Madrid' 'Malasaña-Universidad, Madrid'
#  'Palos de Moguer, Madrid' 'San Blas, Madrid' 'Prosperidad, Madrid'
#  'Bellas Vistas, Madrid' 'Niño Jesús, Madrid' 'El Viso, Madrid'
#  'Palacio, Madrid' 'Lista, Madrid' 'Ciudad Lineal, Madrid'
#  'Lavapiés-Embajadores, Madrid' 'Salvador, Madrid' 'Almagro, Madrid'
#  'Fuente del Berro, Madrid' 'Gaztambide, Madrid' 'Acacias, Madrid'
# ...

# %%
'''
Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
'''
salamanca_rows = ds[ds['address'] == 'Barrio de Salamanca, Madrid']

# Find the row with the highest price
#most_expensive_salamanca = salamanca_rows.loc[salamanca_rows['price'].mean()]
mean_price_salamanca = salamanca_rows['price'].mean()

#print(mean_price_salamanca)
answer = (f"The mean price in the Salamanca Neighborhood in Madrid is {mean_price_salamanca}.")
print(answer)
# Out:
# The mean price in the Salamanca Neighborhood in Madrid is 1759841.2698412698.

# %%
'''
# TODO
Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.
'''

import pandas as pd
import matplotlib.pyplot as plt


# Filter DataFrame for 'barrio de salamanca, Madrid'
salamanca_prices = ds[ds['address'] == 'Barrio de Salamanca, Madrid']['price']/ 1000000



# Rest of your code to create the histogram
plt.hist(salamanca_prices)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Prices in Barrio de Salamanca')
plt.show()

# %%
import pandas as pd

# Assuming 'ds' is your dataset and 'price' and 'area' are column names
# Group data by area and calculate mean price
mean_prices_by_area = ds.groupby('address')['price'].mean()

# Find the area with the highest mean price
highest_mean_price_area = mean_prices_by_area.idxmax()

# Get the highest mean price itself
highest_mean_price = mean_prices_by_area.max()

print(f"Area with the highest mean price: {highest_mean_price_area}")
print(f"Highest mean price: {highest_mean_price:.2f}")  # Format price with 2 decimals
# Out:
# Area with the highest mean price: Recoletos, Madrid
# Highest mean price: 2661437.50

# %%
import pandas as pd

# Assuming 'ds' is your dataset and 'price' and 'area' are column names
# Group data by area and calculate mean price
mean_prices_by_area = ds.groupby('address')['price'].mean()

# Sort by mean price in descending order and get top 5
top_5_areas = mean_prices_by_area.sort_values(ascending=False).head(5)

# Print results with area and corresponding mean price
for area, mean_price in top_5_areas.items():
    print(f"Area: {area}, Mean Price: {mean_price:.2f}")
# Out:
# Area: Recoletos, Madrid, Mean Price: 2661437.50
# Area: Almagro, Madrid, Mean Price: 2445473.68
# Area: Nueva España, Madrid, Mean Price: 2342500.00
# Area: Castellana, Madrid, Mean Price: 2316055.56
# Area: Conde Orgaz-Piovera, Madrid, Mean Price: 2152000.00

# %%
Recoletos_prices = ds[ds['address'] == 'Recoletos, Madrid']['price']/ 1000000

#The most expensive area. by mean..


# Rest of your code to create the histogram
plt.hist(Recoletos_prices, bins=15, color='green')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Prices in Recoletos')
plt.show()

# %%
import pandas as pd

# Assuming 'price' and 'sqft' (or similar names) are your existing columns
# Create the new column 'price_per_sqft'
ds['price_per_sqft'] = ds['price'] / ds['sqft']

# Handle potential division by zero (optional)

# Print the DataFrame to see the new column
ds

#calculations seem off.
# Out:
#                                                url  \
# 0    https://www.idealista.com/inmueble/104027174/
# 1    https://www.idealista.com/inmueble/102321942/
# 2    https://www.idealista.com/inmueble/103334142/
# 3    https://www.idealista.com/inmueble/104161987/
# 4    https://www.idealista.com/inmueble/103989666/
# ..                                             ...
# 910  https://www.idealista.com/inmueble/103960809/
# 911  https://www.idealista.com/inmueble/103494183/
# 912  https://www.idealista.com/inmueble/102107584/
# 913   https://www.idealista.com/inmueble/99991709/
# 914  https://www.idealista.com/inmueble/103315777/
#
#                                             listingUrl  \
# 0    https://www.idealista.com/venta-viviendas/madr...
# 1    https://www.idealista.com/venta-viviendas/madr...
# 2    https://www.idealista.com/venta-viviendas/madr...
# 3    https://www.idealista.com/venta-viviendas/madr...
# 4    https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
ds['address'].unique()
# Out:
# array(['Recoletos, Madrid', 'Castellana, Madrid', 'Hortaleza, Madrid',
#        'Chamartín, Madrid', 'Cuatro Caminos, Madrid', 'Goya, Madrid',
#        'Aravaca, Madrid', 'Sol, Madrid',
#        'Bernabéu-Hispanoamérica, Madrid', 'Vallehermoso, Madrid',
#        'Huertas-Cortes, Madrid', 'Chamberí, Madrid',
#        'Nueva España, Madrid', 'Conde Orgaz-Piovera, Madrid',
#        'Chueca-Justicia, Madrid', 'Argüelles, Madrid',
#        'Nuevos Ministerios-Ríos Rosas, Madrid', 'Centro, Madrid',
#        'Moncloa, Madrid', 'Retiro, Madrid', 'Barrio de Salamanca, Madrid',
#        'Peñagrande, Madrid', 'Mirasierra, Madrid', 'Fuencarral, Madrid',
#        'Comillas, Madrid', 'Malasaña-Universidad, Madrid',
#        'Palos de Moguer, Madrid', 'San Blas, Madrid',
#        'Prosperidad, Madrid', 'Bellas Vistas, Madrid',
#        'Niño Jesús, Madrid', 'El Viso, Madrid', 'Palacio, Madrid',
#        'Lista, Madrid', 'Ciudad Lineal, Madrid',
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

'''
Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
Hint: You can make a scatter plot and then write a conclusion about it
'''


# Extract price and square_feet columns from the DataFrame
prices = ds['price']
square_feet = ds['sqft']

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(square_feet, prices, color='blue', alpha=0.7)
plt.title('Relationship between Price and Square Feet')
plt.xlabel('Square Feet')
plt.ylabel('Price ($)')
plt.grid(True)
plt.show()

# %%
'''
Exercise 12. How many real estate agencies the dataset contains? (★★☆)
Print the obtained value
'''
unique_advertisers = ds['advertiserName'].nunique()
print(f'There are {unique_advertisers} in the dataset')
# Out:
# There are 118 in the dataset

# %%
ds.columns
# Out:
# Index(['url', 'listingUrl', 'title', 'id', 'price', 'baths', 'rooms', 'sqft',
#        'address', 'typology', 'advertiserName', 'price_per_sqft'],
#       dtype='object')

# %%
'''
# TODO
Exercise 13. Which adress (area) contains the most houses? (★★☆)
'''

# Assuming 'City' is the column with city names and 'HouseID' is the column with house identifiers
houses_by_city = ds.groupby('address')['id'].count()
city_with_most_houses = houses_by_city.idxmax()
max_houses = houses_by_city.max()
print(f"The city with the most houses is: {city_with_most_houses} with {max_houses} houses")
# Out:
# The city with the most houses is: Barrio de Salamanca, Madrid with 63 houses

# %%
import matplotlib.pyplot as plt

houses_by_city.plot(kind='bar', figsize=(10, 5))
plt.title('Number of Houses by City')
plt.xlabel('address')
plt.ylabel('Number of Houses')
plt.show()

# %%
#Hint: Create a new column called pps (price per square) and then analyse the values <- AN EXAMPLE OF FEATURE ENGINEERING

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and 'Price' is the column with prices
medians = ds['price'].median()

# Plotting the median
plt.bar('Median Price', medians)
plt.title('Median Price of Houses')
plt.ylabel('Price')
plt.show()

# %%
ds.describe()
# Out:
#                  id         price       baths       rooms         sqft  \
# count  9.150000e+02  9.150000e+02  915.000000  915.000000   915.000000
# mean   1.020578e+08  1.290575e+06    2.900546    3.474317   217.238251
# std    5.338810e+06  1.036640e+06    1.626487    1.594625   191.745826
# min    2.547319e+07  1.220000e+05    1.000000    0.000000    14.000000
# 25%    1.019509e+08  6.250000e+05    2.000000    2.000000   104.000000
# 50%    1.031510e+08  9.900000e+05    3.000000    3.000000   158.000000
# 75%    1.037703e+08  1.650000e+06    4.000000    4.000000   264.000000
# max    1.042055e+08  8.900000e+06   12.000000   12.000000  1768.000000
#
#        price_per_sqft
# count      915.000000
# mean      6400.946033
# std       2800.261872
# min       1198.083067
# 25%       4394.450062
# 50%       5760.869565
# 75%       7937.331435
# max      21299.638989

# %%
import pandas as pd
import matplotlib.pyplot as plt

median_prices = ds.groupby('address')['price'].median()

median_prices.plot(kind='bar', figsize=(15, 5))
plt.title('Median Price of Houses by Area')
plt.xlabel('Area')
plt.ylabel('Median Price')
plt.xticks(rotation=45)
plt.show()

# %%
"""

from matplotlib import pyplot as plt
from matplotlib.ticker import FuncFormatter

def millions_formatter(x, pos):
    return f'{x / 1000000}'


median_prices = ds.groupby('address')['price'].median()
median_prices.plot(kind='bar', figsize=(15, 5))
ax.yaxis.set_major_formatter(FuncFormatter(millions_formatter))
plt.xticks(rotation=45)
ax.set_ylabel('value (in millions)')
plt.show()"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-472-abf0157f5d90> in <cell line: 10>()
#       8 median_prices = ds.groupby('address')['price'].median()
#       9 median_prices.plot(kind='bar', figsize=(15, 5))
# ---> 10 ax.yaxis.set_major_formatter(FuncFormatter(millions_formatter))
#      11 plt.xticks(rotation=45)
#      12 ax.set_ylabel('value (in millions)')
#
# NameError: name 'ax' is not defined

# %%
ds.columns
# Out:
# Index(['url', 'listingUrl', 'title', 'id', 'price', 'baths', 'rooms', 'sqft',
#        'address', 'typology', 'advertiserName', 'price_per_sqft'],
#       dtype='object')

# %%
"""
Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
Print both values for each variable
"""

salamanca_ds = ds[ds['address']== 'Barrio de Salamanca, Madrid']
mean_values = salamanca_ds[['price', 'baths', 'sqft', 'rooms']].mean()
print("Sample Mean:\n", mean_values)
variance_values = salamanca_ds[['price', 'baths', 'sqft', 'rooms']].var()
print("Sample Variance:\n", variance_values)
# Out:
# Sample Mean:
#  price    1.759841e+06
# baths    2.825397e+00
# sqft     1.852698e+02
# rooms    3.317460e+00
# dtype: float64
# Sample Variance:
#  price    1.669393e+12
# baths    9.851510e-01
# sqft     6.858168e+03
# rooms    1.316948e+00
# dtype: float64

# %%
median_prices.plot(kind='bar', figsize=(10, 5))
plt.title('Median Price of Houses by Area')
plt.xlabel('Area')
plt.ylabel('Median Price')
plt.show()

# %%
ds['address'].nunique()
# Out:
# 105

# %%
'''




# TODO
Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

'''

import pandas as pd

# Assuming 'df' is your DataFrame, 'Area' is the column with areas, 'Price' is the column with prices, and 'Address' is the column with addresses

# Group by 'Area' and find the index of the most expensive house in each group
most_expensive_house_indices = ds.groupby('address')['price'].idxmax()

# Use the indices to retrieve the corresponding 'Address' and 'Price' for each area
most_expensive_houses = ds.loc[most_expensive_house_indices, ['id', 'price']]

# Reset the index to make 'Area' a column again
most_expensive_houses.reset_index(inplace=True)

# Rename the columns for clarity
most_expensive_houses.columns = ['address', 'id', 'Price']

print(most_expensive_houses)
# Out:
#      address         id    Price
# 0        518  104144435   155000
# 1        119  103920819   979000
# 2        475  103648960  4200000
# 3        289  103985051   689000
# 4        605  102373757   255900
# ..       ...        ...      ...
# 100      775  102470726   310000
# 101      106  102169762   910000
# 102      514   98412896   899000
# 103      466   97659976   239900
# 104      139  104156893   164000
#
# [105 rows x 3 columns]

# %%
'''

# TODO
Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot

Hint: You can help yourself reviewing the multihist demo of Matplotlib
'''
# Out:
# '\n\n# TODO\nExercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)\nFor the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot\n\nHint: You can help yourself reviewing the multihist demo of Matplotlib\n'

# %%
'''

Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
Hint: Create a new column called pps (price per square) and then analyse the values

# TODO
Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
Hint: make a scatter plot of each population using subplots.

# TODO
Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

from ipyleaflet import Map, basemaps

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
    basemap=basemaps.Stamen.Terrain)
map
## HERE: plot the coordinates of the estates

'''
# Out:
# '\n\nExercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)\nHint: Create a new column called pps (price per square) and then analyse the values\n\n# TODO\nExercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)\nHint: make a scatter plot of each population using subplots.\n\n# TODO\nExercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)\nExecute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map\n\nfrom ipyleaflet import Map, basemaps\n\n# Map centred o
# ...

# %%
from ipyleaflet import Map, Marker
center = (52.204793, 360.121558)
map = Map(center=center, zoom=10)

# Add a draggable marker to the map
# Dragging the marker updates the marker.location value in Python
marker = Marker(location=center, draggable=True)
map.add_control(marker)

display(map)
# Out:
# Map(center=[52.204793, 360.121558], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %%
from ipyleaflet import Map, Marker

center = (52.204793, 360.121558)

m = Map(center=center, zoom=10)

marker = Marker(location=center, draggable=True)
m.add(marker);

display(m)

# Now that the marker is on the Map, you can drag it with your mouse,
# it will automatically update the `marker.location` attribute in Python

# You can also update the marker location from Python, that will update the
# marker location on the Map:
marker.location = (50, 356)
# Out:
# Map(center=[52.204793, 360.121558], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# So these were some miscellaneous data mining on the Dataset that I have.
# Some that would normally be included in the EDA process. Therefore we will bypass Step 1: Problem statement and data collection, Step 2: Exploration and data cleaning, Step 3: Analysis of univariate variables.
#
#
# Therefore we will only showcase Step 4: Analysis of multivariate variables
# Step5: Feature Engineering
# Step 6: Feature Selection
#
#
# Some Possible Questions I could answer are...
# 2. Rental Price Prediction Model:
#
# Similar to price prediction but for monthly rent.
# Target Variable: Monthly rent
# Input Variables: Same as price prediction model
# 3. Rent vs. Buy Recommendation Model:
#
# This model can predict if it's financially better to rent or buy an apartment based on various factors.
# Target Variable: Categorical (Rent or Buy)
# Input Variables: Price, rent, interest rates, historical price/rent data, expected future price/rent changes
#
#
# Question I want to answer is...
# **Target Variable: Price of the apartment**

# %% [markdown]
# **Step 4: Analysis of multivariate variablest**

# %%
#Before this are there any two features that I can add?
ds
# Out:
#                                                url  \
# 0    https://www.idealista.com/inmueble/104027174/
# 1    https://www.idealista.com/inmueble/102321942/
# 2    https://www.idealista.com/inmueble/103334142/
# 3    https://www.idealista.com/inmueble/104161987/
# 4    https://www.idealista.com/inmueble/103989666/
# ..                                             ...
# 910  https://www.idealista.com/inmueble/103960809/
# 911  https://www.idealista.com/inmueble/103494183/
# 912  https://www.idealista.com/inmueble/102107584/
# 913   https://www.idealista.com/inmueble/99991709/
# 914  https://www.idealista.com/inmueble/103315777/
#
#                                             listingUrl  \
# 0    https://www.idealista.com/venta-viviendas/madr...
# 1    https://www.idealista.com/venta-viviendas/madr...
# 2    https://www.idealista.com/venta-viviendas/madr...
# 3    https://www.idealista.com/venta-viviendas/madr...
# 4    https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
ds.sqft.unique()
# Out:
# array([ 183,  170,  270,  248,  116,  360,  305,  112,  153,  291,  132,
#         160,  229,  284,  178,  169,  283,  886,  214,  292,  367,  473,
#         261,  306,  438,  117,  300,  173,  240,  242,  108,  485,  450,
#          95,  175,  154,  156,  168,  334, 1150,  265,  127,  125,  133,
#          75,  372,  212,  236,  269,  105,  124,  488,   76,  199,   97,
#          91,  259,  452,  247,   52,   93,  102,  200,   51,  399,  237,
#         101,  201,  146,   69,  148,  107,   40,  143,  145,  213,  139,
#         348,   60,  368,   88, 1525,  388,  580,  141,  605,  780,  258,
#         720,  215,  188,  164,  207,  106,  443,  158,  135,  234,  231,
#          74,  262,  414,  254,  410,  890,  220, 1500,  177,  179,   86,
#         352,  165,   78,  174,  193,  264,  137,  104,  400,   67,  275,
#         185,   68,   57,  216,  121,   80,   87,  109,  287,   82,   94,
#         126,   46,   98,  103,  370,   45,  302,  195,   73,   48,  440,
# ...

# %%
ds = ds.rename(columns={'price_per_sqft': 'price_per_m2'})
ds
# Out:
#                                                url  \
# 0    https://www.idealista.com/inmueble/104027174/
# 1    https://www.idealista.com/inmueble/102321942/
# 2    https://www.idealista.com/inmueble/103334142/
# 3    https://www.idealista.com/inmueble/104161987/
# 4    https://www.idealista.com/inmueble/103989666/
# ..                                             ...
# 910  https://www.idealista.com/inmueble/103960809/
# 911  https://www.idealista.com/inmueble/103494183/
# 912  https://www.idealista.com/inmueble/102107584/
# 913   https://www.idealista.com/inmueble/99991709/
# 914  https://www.idealista.com/inmueble/103315777/
#
#                                             listingUrl  \
# 0    https://www.idealista.com/venta-viviendas/madr...
# 1    https://www.idealista.com/venta-viviendas/madr...
# 2    https://www.idealista.com/venta-viviendas/madr...
# 3    https://www.idealista.com/venta-viviendas/madr...
# 4    https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
#ds['price_per_m2'].sort()
sorted_ppm = ds.sort_values(by='price_per_m2', ascending=False)
sorted_ppm
# Out:
#                                                url  \
# 352  https://www.idealista.com/inmueble/103343874/
# 6    https://www.idealista.com/inmueble/103363210/
# 242  https://www.idealista.com/inmueble/103637124/
# 22   https://www.idealista.com/inmueble/101980713/
# 912  https://www.idealista.com/inmueble/102107584/
# ..                                             ...
# 825  https://www.idealista.com/inmueble/104179896/
# 788  https://www.idealista.com/inmueble/103628504/
# 466   https://www.idealista.com/inmueble/97659976/
# 906   https://www.idealista.com/inmueble/97957477/
# 403  https://www.idealista.com/inmueble/102020886/
#
#                                             listingUrl  \
# 352  https://www.idealista.com/venta-viviendas/madr...
# 6    https://www.idealista.com/venta-viviendas/madr...
# 242  https://www.idealista.com/venta-viviendas/madr...
# 22   https://www.idealista.com/venta-viviendas/madr...
# 912  https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
ds['price_per_sqm'] = ds['price_per_m2'].round(2)  # Replace 'price_per_sqm' with your actual column name

# %%
ds['sqm']=ds['sqft']

# %%
ds
# Out:
#                                                url  \
# 0    https://www.idealista.com/inmueble/104027174/
# 1    https://www.idealista.com/inmueble/102321942/
# 2    https://www.idealista.com/inmueble/103334142/
# 3    https://www.idealista.com/inmueble/104161987/
# 4    https://www.idealista.com/inmueble/103989666/
# ..                                             ...
# 910  https://www.idealista.com/inmueble/103960809/
# 911  https://www.idealista.com/inmueble/103494183/
# 912  https://www.idealista.com/inmueble/102107584/
# 913   https://www.idealista.com/inmueble/99991709/
# 914  https://www.idealista.com/inmueble/103315777/
#
#                                             listingUrl  \
# 0    https://www.idealista.com/venta-viviendas/madr...
# 1    https://www.idealista.com/venta-viviendas/madr...
# 2    https://www.idealista.com/venta-viviendas/madr...
# 3    https://www.idealista.com/venta-viviendas/madr...
# 4    https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
'''
def remove_ppm_outliers(ds):
  ds_out = pd.Dataframe()
  for key, subds in ds.groupby('address'):
    m = np.mean(subds.price_per_sqm)
    st = np.std(subds.price_per_sqm)
    reduced_ds = subds[(subds.price_per_sqm>(m-st) & (subds.price_per_sqm))]
    ds_out = pd.concat([ds_out,reduced_ds],ignore_index=True)
  return ds_out
'''
# Out:
# "\ndef remove_ppm_outliers(ds):\n  ds_out = pd.Dataframe()\n  for key, subds in ds.groupby('address'):\n    m = np.mean(subds.price_per_sqm)\n    st = np.std(subds.price_per_sqm)\n    reduced_ds = subds[(subds.price_per_sqm>(m-st) & (subds.price_per_sqm))]\n    ds_out = pd.concat([ds_out,reduced_ds],ignore_index=True)\n  return ds_out\n"

# %%
ds.drop('price_per_m2', axis=1)
# Out:
#                                                url  \
# 0    https://www.idealista.com/inmueble/104027174/
# 1    https://www.idealista.com/inmueble/102321942/
# 2    https://www.idealista.com/inmueble/103334142/
# 3    https://www.idealista.com/inmueble/104161987/
# 4    https://www.idealista.com/inmueble/103989666/
# ..                                             ...
# 910  https://www.idealista.com/inmueble/103960809/
# 911  https://www.idealista.com/inmueble/103494183/
# 912  https://www.idealista.com/inmueble/102107584/
# 913   https://www.idealista.com/inmueble/99991709/
# 914  https://www.idealista.com/inmueble/103315777/
#
#                                             listingUrl  \
# 0    https://www.idealista.com/venta-viviendas/madr...
# 1    https://www.idealista.com/venta-viviendas/madr...
# 2    https://www.idealista.com/venta-viviendas/madr...
# 3    https://www.idealista.com/venta-viviendas/madr...
# 4    https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
import matplotlib

# %%
#ds.address=Recoletos.price.max()
max_price_for_recoletos = ds[ds['address'] == 'Recoletos, Madrid']['price'].max()
max_price_for_recoletos
# Out:
# 8900000

# %%
max_price_for_recoletos = ds[(ds['address'] == 'Recoletos, Madrid') & (ds['rooms'] == 3)]['price'].max()
max_price_for_recoletos
# Out:
# 5000000

# %%
def plot_scatter_chart(ds,address):
  rm2 = ds[(ds.address==address) & (ds.rooms==2)]
  rm3 = ds[(ds.address==address) & (ds.rooms==3)]
  matplotlib.rcParams['figure.figsize'] = (15,10)
  plt.scatter(rm2.sqm,rm2.price/1000000,color='blue',label='2 Rms', s=50)
  plt.scatter(rm3.sqm,rm3.price/1000000, marker= '+', color='green',label='3 Rms', s=50)
  plt.xlabel("Total Square Meter Area")
  plt.ylabel("Price (in Millions)")
  plt.title(address)
  plt.legend()


#plot_scatter_chart(ds,'Barrio de Salamanca, Madrid')

plot_scatter_chart(ds,'Recoletos, Madrid')

# %%
ds.drop('price_per_m2', axis=1)
# Out:
#                                                url  \
# 0    https://www.idealista.com/inmueble/104027174/
# 1    https://www.idealista.com/inmueble/102321942/
# 2    https://www.idealista.com/inmueble/103334142/
# 3    https://www.idealista.com/inmueble/104161987/
# 4    https://www.idealista.com/inmueble/103989666/
# ..                                             ...
# 910  https://www.idealista.com/inmueble/103960809/
# 911  https://www.idealista.com/inmueble/103494183/
# 912  https://www.idealista.com/inmueble/102107584/
# 913   https://www.idealista.com/inmueble/99991709/
# 914  https://www.idealista.com/inmueble/103315777/
#
#                                             listingUrl  \
# 0    https://www.idealista.com/venta-viviendas/madr...
# 1    https://www.idealista.com/venta-viviendas/madr...
# 2    https://www.idealista.com/venta-viviendas/madr...
# 3    https://www.idealista.com/venta-viviendas/madr...
# 4    https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
ds2 = ds

# %%
ds2
# Out:
#                                                url  \
# 0    https://www.idealista.com/inmueble/104027174/
# 1    https://www.idealista.com/inmueble/102321942/
# 2    https://www.idealista.com/inmueble/103334142/
# 3    https://www.idealista.com/inmueble/104161987/
# 4    https://www.idealista.com/inmueble/103989666/
# ..                                             ...
# 910  https://www.idealista.com/inmueble/103960809/
# 911  https://www.idealista.com/inmueble/103494183/
# 912  https://www.idealista.com/inmueble/102107584/
# 913   https://www.idealista.com/inmueble/99991709/
# 914  https://www.idealista.com/inmueble/103315777/
#
#                                             listingUrl  \
# 0    https://www.idealista.com/venta-viviendas/madr...
# 1    https://www.idealista.com/venta-viviendas/madr...
# 2    https://www.idealista.com/venta-viviendas/madr...
# 3    https://www.idealista.com/venta-viviendas/madr...
# 4    https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
import pandas as pd
# Function to remove ", Madrid" from addresses
def remove_madrid(address):
  return address.rsplit(",", 1)[0]  # Split at last comma, keep part before

ds2['address'] = ds2['address'].apply(remove_madrid)

# %%
ds['address'] = ds2['address']

# %%
ds['address'].unique()
# Out:
# array(['Recoletos', 'Castellana', 'Hortaleza', 'Chamartín',
#        'Cuatro Caminos', 'Goya', 'Aravaca', 'Sol',
#        'Bernabéu-Hispanoamérica', 'Vallehermoso', 'Huertas-Cortes',
#        'Chamberí', 'Nueva España', 'Conde Orgaz-Piovera',
#        'Chueca-Justicia', 'Argüelles', 'Nuevos Ministerios-Ríos Rosas',
#        'Centro', 'Moncloa', 'Retiro', 'Barrio de Salamanca', 'Peñagrande',
#        'Mirasierra', 'Fuencarral', 'Comillas', 'Malasaña-Universidad',
#        'Palos de Moguer', 'San Blas', 'Prosperidad', 'Bellas Vistas',
#        'Niño Jesús', 'El Viso', 'Palacio', 'Lista', 'Ciudad Lineal',
#        'Lavapiés-Embajadores', 'Salvador', 'Almagro', 'Fuente del Berro',
#        'Gaztambide', 'Acacias', 'Arapiles', 'Guindalera',
#        'Ciudad Universitaria', 'Puerta del Ángel', 'Ventilla-Almenara',
#        'Rejas', 'Pau de Carabanchel', 'Zofío', 'La Paz', 'Valdezarza',
#        'Pacífico', 'Costillares', 'Trafalgar', 'Simancas', 'Ibiza',
# ...

# %%
ds['address'].unique()
# Out:
# array(['Recoletos', 'Castellana', 'Hortaleza', 'Chamartín',
#        'Cuatro Caminos', 'Goya', 'Aravaca', 'Sol',
#        'Bernabéu-Hispanoamérica', 'Vallehermoso', 'Huertas-Cortes',
#        'Chamberí', 'Nueva España', 'Conde Orgaz-Piovera',
#        'Chueca-Justicia', 'Argüelles', 'Nuevos Ministerios-Ríos Rosas',
#        'Centro', 'Moncloa', 'Retiro', 'Barrio de Salamanca', 'Peñagrande',
#        'Mirasierra', 'Fuencarral', 'Comillas', 'Malasaña-Universidad',
#        'Palos de Moguer', 'San Blas', 'Prosperidad', 'Bellas Vistas',
#        'Niño Jesús', 'El Viso', 'Palacio', 'Lista', 'Ciudad Lineal',
#        'Lavapiés-Embajadores', 'Salvador', 'Almagro', 'Fuente del Berro',
#        'Gaztambide', 'Acacias', 'Arapiles', 'Guindalera',
#        'Ciudad Universitaria', 'Puerta del Ángel', 'Ventilla-Almenara',
#        'Rejas', 'Pau de Carabanchel', 'Zofío', 'La Paz', 'Valdezarza',
#        'Pacífico', 'Costillares', 'Trafalgar', 'Simancas', 'Ibiza',
# ...

# %%
#The drop first being true is to avoid the dummy variable trap
dummies = pd.get_dummies(ds.address, drop_first=True)
dummies.head()
# Out:
#    Acacias  Almagro  Almendrales  Amposta  Arapiles  Aravaca  Arganzuela  \
# 0    False    False        False    False     False    False       False
# 1    False    False        False    False     False    False       False
# 2    False    False        False    False     False    False       False
# 3    False    False        False    False     False    False       False
# 4    False    False        False    False     False    False       False
#
#    Argüelles  Barajas  Barrio de Salamanca  Bellas Vistas  \
# 0      False    False                False          False
# 1      False    False                False          False
# 2      False    False                False          False
# 3      False    False                False          False
# 4      False    False                False          False
#
#    Bernabéu-Hispanoamérica  Berruguete  Buena Vista  Butarque  Campamento  \
# 0                    False       False        False     False       False
# ...

# %%
#Now we will use One-HotEncoding
ds.columns
# Out:
# Index(['url', 'listingUrl', 'title', 'id', 'price', 'baths', 'rooms', 'sqft',
#        'address', 'typology', 'advertiserName', 'price_per_m2',
#        'price_per_sqm', 'sqm'],
#       dtype='object')

# %%
ds1 = ds.drop(['url','listingUrl','title','id','typology','advertiserName','price_per_m2','sqft','price_per_sqm'], axis=1)

# %%
ds1
# Out:
#        price  baths  rooms              address  sqm
# 0    1920000      3      3            Recoletos  183
# 1    1995000      3      3           Castellana  170
# 2    1300000      3      4            Hortaleza  270
# 3    1650000      3      3            Chamartín  248
# 4    1590750      3      3            Recoletos  116
# ..       ...    ...    ...                  ...  ...
# 910  1475000      4      5    Cuzco-Castillejos  376
# 911   865000      2      2            Trafalgar  127
# 912  7900000      5      4  Barrio de Salamanca  473
# 913   990000      4      6        Ciudad Lineal  293
# 914  1080000      2      4               Tetuán  270
#
# [915 rows x 5 columns]

# %%
ds3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-515-5bb49dc9eaf4> in <cell line: 1>()
# ----> 1 ds3
#
# NameError: name 'ds3' is not defined

# %%
ds2 = pd.concat([ds1, dummies],axis='columns')

# %%
ds3 = ds2.drop('address', axis=1)
ds3.head()
# Out:
#      price  baths  rooms  sqm  Acacias  Almagro  Almendrales  Amposta  \
# 0  1920000      3      3  183    False    False        False    False
# 1  1995000      3      3  170    False    False        False    False
# 2  1300000      3      4  270    False    False        False    False
# 3  1650000      3      3  248    False    False        False    False
# 4  1590750      3      3  116    False    False        False    False
#
#    Arapiles  Aravaca  Arganzuela  Argüelles  Barajas  Barrio de Salamanca  \
# 0     False    False       False      False    False                False
# 1     False    False       False      False    False                False
# 2     False    False       False      False    False                False
# 3     False    False       False      False    False                False
# 4     False    False       False      False    False                False
#
#    Bellas Vistas  Bernabéu-Hispanoamérica  Berruguete  Buena Vista  Butarque  \
# ...

# %%
X = ds3.drop('price', axis=1)
X.head()
# Out:
#    baths  rooms  sqm  Acacias  Almagro  Almendrales  Amposta  Arapiles  \
# 0      3      3  183    False    False        False    False     False
# 1      3      3  170    False    False        False    False     False
# 2      3      4  270    False    False        False    False     False
# 3      3      3  248    False    False        False    False     False
# 4      3      3  116    False    False        False    False     False
#
#    Aravaca  Arganzuela  Argüelles  Barajas  Barrio de Salamanca  \
# 0    False       False      False    False                False
# 1    False       False      False    False                False
# 2    False       False      False    False                False
# 3    False       False      False    False                False
# 4    False       False      False    False                False
#
#    Bellas Vistas  Bernabéu-Hispanoamérica  Berruguete  Buena Vista  Butarque  \
# ...

# %%
y = ds3.price
y.head()
# Out:
# 0    1920000
# 1    1995000
# 2    1300000
# 3    1650000
# 4    1590750
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test, y_test)
# Out:
# -8.434409190498792e+17

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
cross_val_score(LinearRegression(),X,y, cv=cv)
# Out:
# array([-9.64062831e+18, -1.40397467e+17, -9.82269930e+14, -2.45605002e+17,
#         6.62076317e-01])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor


def find_best_model_using_gridsearchcv(X,y):
  algos = {
      'linear_regression' : {
          'model': LinearRegression(),
          'params' : {
              'fit_intercept' : [True, False],
              'copy_X': [True, False],
              'n_jobs': [True, False],
              'positive': [True, False]
          }
      },
      'lasso': {
          'model': Lasso(),
          'params': {
              'alpha': [1,2],
              'selection': ['random', 'cyclic']
          }
      },
      'decision_tree': {
          'model': DecisionTreeRegressor(),
          'params': {
              'criterion': ['mse','friedman_mse'],
              'splitter': ['best', 'random']
          }
      }
  }

  scores = []
  cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
  for algo_name, config in algos.items():
    gs = GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
    gs.fit(X,y)
    scores.append({
        'model': algo_name,
        'best_score': gs.best_score_,
        'best_params': gs.best_params_
    })

  return pd.DataFrame(scores,columns=['model','best_score','best_params'])


find_best_model_using_gridsearchcv(X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.137e+14, tolerance: 8.213e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.205e+14, tolerance: 8.067e+10
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression(copy_X=True, fit_intercept=False, n_jobs=True, positive=True)
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test, y_test)
# Out:
# 0.6327896452855497

# %%
ds3
# Out:
#        price  baths  rooms  sqm  Acacias  Almagro  Almendrales  Amposta  \
# 0    1920000      3      3  183    False    False        False    False
# 1    1995000      3      3  170    False    False        False    False
# 2    1300000      3      4  270    False    False        False    False
# 3    1650000      3      3  248    False    False        False    False
# 4    1590750      3      3  116    False    False        False    False
# ..       ...    ...    ...  ...      ...      ...          ...      ...
# 910  1475000      4      5  376    False    False        False    False
# 911   865000      2      2  127    False    False        False    False
# 912  7900000      5      4  473    False    False        False    False
# 913   990000      4      6  293    False    False        False    False
# 914  1080000      2      4  270    False    False        False    False
#
#      Arapiles  Aravaca  Arganzuela  Argüelles  Barajas  Barrio de Salamanca  \
# ...

# %%
import numpy as np

# %%
def predict_price(location,sqm,baths,rooms):
  loc_index = np.where(X.columns==location)[0][0]

  x = np.zeros(len(X.columns))
  x[0] = sqm
  x[1] = baths
  x[2] = rooms
  if loc_index >= 0:
    x[loc_index] = 1

  return lr_clf.predict([x])[0]

# %%
predict_price('Almagro', 200,2,3)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 28089089.416342303

# %%
predict_price('Almagro', 120,1,3)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 17271029.357722245

# %%
predict_price('Barajas', 70,1,1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 9468627.215517033

# %%
import pickle
with open ('Madrid_home_prices.pickle','wb') as f:
  pickle.dump(lr_clf,f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json", "w") as f:
  f.write(json.dumps(columns))

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Assuming you have already fit the model using lr_clf.fit(X_train, y_train)

# Predict prices for the test data
y_pred = lr_clf.predict(X_test)

# Scatter plot with predicted prices on x-axis and actual prices on y-axis
plt.scatter(y_pred, y_test)

# ... rest of the plotting code (adding regression line, labels, title, etc.)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Assuming you have your actual prices (y_test) and predicted prices from the model (y_pred)

# Scatter plot with predicted prices on x-axis and actual prices on y-axis
plt.scatter(y_pred, y_test)

# Add a regression line
plt.plot(y_pred, y_pred, color='red')  # This is the perfect prediction line (y=x)

# Label the axes
plt.xlabel('Predicted Prices')
plt.ylabel('Actual Prices')

# Add a title
plt.title('Actual vs. Predicted Prices (Linear Regression)')

# Show the plot
plt.show()
