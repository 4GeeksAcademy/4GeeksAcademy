# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_excel('c:/Users/gfern/OneDrive/Escritorio/4GeeksAcademy/Datos_Rotacion.xlsx')
df.head()
# Out:
#   Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0       Si    41         Raramente       Ventas               1          2
# 1       No    49    Frecuentemente          IyD               8          1
# 2       Si    37         Raramente          IyD               2          2
# 3       No    33    Frecuentemente          IyD               3          4
# 4       No    27         Raramente          IyD               2          1
#
#   Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 0        Ciencias                       2      F         Ejecutivo_Ventas
# 1        Ciencias                       3      M  Investigador_Cientifico
# 2            Otra                       4      M      Tecnico_Laboratorio
# 3        Ciencias                       4      F  Investigador_Cientifico
# 4           Salud                       1      M      Tecnico_Laboratorio
#
# ...

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rotación                     1470 non-null   object
#  1   Edad                         1470 non-null   int64
#  2   Viaje de Negocios            1470 non-null   object
#  3   Departamento                 1470 non-null   object
#  4   Distancia_Casa               1470 non-null   int64
#  5   Educación                    1470 non-null   int64
#  6   Campo_Educación              1470 non-null   object
#  7   Satisfacción_Ambiental       1470 non-null   int64
#  8   Genero                       1470 non-null   object
#  9   Cargo                        1470 non-null   object
#  10  Satisfación_Laboral          1470 non-null   int64
#  11  Estado_Civil                 1470 non-null   object
#  12  Ingreso_Mensual              1470 non-null   int64
# ...

# %%
max(df.isnull().sum(axis=1))    # Maximos cantidad de datos faltantes para un registro
# Out:
# 0

# %%
df.dropna(axis=0)   # quitar filas con valores faltantes
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0          Si    41         Raramente       Ventas               1          2
# 1          No    49    Frecuentemente          IyD               8          1
# 2          Si    37         Raramente          IyD               2          2
# 3          No    33    Frecuentemente          IyD               3          4
# 4          No    27         Raramente          IyD               2          1
# ...       ...   ...               ...          ...             ...        ...
# 1465       No    36    Frecuentemente          IyD              23          2
# 1466       No    39         Raramente          IyD               6          1
# 1467       No    27         Raramente          IyD               4          3
# 1468       No    49    Frecuentemente       Ventas               2          3
# 1469       No    34         Raramente          IyD               8          3
#
# ...

# %%
df.dropna(axis=1)   # quitar columnas con valores faltantes
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0          Si    41         Raramente       Ventas               1          2
# 1          No    49    Frecuentemente          IyD               8          1
# 2          Si    37         Raramente          IyD               2          2
# 3          No    33    Frecuentemente          IyD               3          4
# 4          No    27         Raramente          IyD               2          1
# ...       ...   ...               ...          ...             ...        ...
# 1465       No    36    Frecuentemente          IyD              23          2
# 1466       No    39         Raramente          IyD               6          1
# 1467       No    27         Raramente          IyD               4          3
# 1468       No    49    Frecuentemente       Ventas               2          3
# 1469       No    34         Raramente          IyD               8          3
#
# ...

# %%
df.fillna(value=0)  # rellena los valores NA con ceros, si existiesen
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0          Si    41         Raramente       Ventas               1          2
# 1          No    49    Frecuentemente          IyD               8          1
# 2          Si    37         Raramente          IyD               2          2
# 3          No    33    Frecuentemente          IyD               3          4
# 4          No    27         Raramente          IyD               2          1
# ...       ...   ...               ...          ...             ...        ...
# 1465       No    36    Frecuentemente          IyD              23          2
# 1466       No    39         Raramente          IyD               6          1
# 1467       No    27         Raramente          IyD               4          3
# 1468       No    49    Frecuentemente       Ventas               2          3
# 1469       No    34         Raramente          IyD               8          3
#
# ...

# %%
df['Estado_Civil'].unique() # Para saber nombre de los valores unicos que toma la columna
# Out:
# array(['Soltero', 'Casado', 'Divorciado'], dtype=object)

# %%
df['Estado_Civil']. nunique() # Para saber cuantos valores unicos que toma la columna
# Out:
# 3

# %%
df.duplicated()   # Verifica datos duplicados en todas las columnas
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
df.duplicated().sum()   # muestra suma de todos los registros duplicados
# Out:
# 0

# %%
df.duplicated('Edad').sum()
# Out:
# 1427

# %%
df.drop_duplicates()
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0          Si    41         Raramente       Ventas               1          2
# 1          No    49    Frecuentemente          IyD               8          1
# 2          Si    37         Raramente          IyD               2          2
# 3          No    33    Frecuentemente          IyD               3          4
# 4          No    27         Raramente          IyD               2          1
# ...       ...   ...               ...          ...             ...        ...
# 1465       No    36    Frecuentemente          IyD              23          2
# 1466       No    39         Raramente          IyD               6          1
# 1467       No    27         Raramente          IyD               4          3
# 1468       No    49    Frecuentemente       Ventas               2          3
# 1469       No    34         Raramente          IyD               8          3
#
# ...

# %%
df.Ingreso_Mensual.mean()
# Out:
# 6502.931292517007

# %%
df.Ingreso_Mensual.median()
# Out:
# 4919.0

# %%
df.Ingreso_Mensual.max()
# Out:
# 19999

# %%
df.Ingreso_Mensual.mode()
# Out:
# 0    2342
# Name: Ingreso_Mensual, dtype: int64

# %%
df.Ingreso_Mensual.argmax()
# Out:
# 190

# %%
df['Viaje de Negocios'].value_counts()
# Out:
# Viaje de Negocios
# Raramente         1043
# Frecuentemente     277
# No_Viaja           150
# Name: count, dtype: int64

# %%
df.Campo_Educación.value_counts()
# Out:
# Campo_Educación
# Ciencias       606
# Salud          464
# Mercadeo       159
# Tecnicos       132
# Otra            82
# Humanidades     27
# Name: count, dtype: int64

# %%
df.groupby('Campo_Educación')['Ingreso_Mensual'].sum().sort_values(ascending=False)
# Out:
# Campo_Educación
# Ciencias       3916753
# Salud          3020657
# Mercadeo       1168425
# Tecnicos        760096
# Otra            497867
# Humanidades     195511
# Name: Ingreso_Mensual, dtype: int64

# %%
df.Ingreso_Mensual.var()    # Varianza Ingreso Mensual
# Out:
# 22164857.07151841

# %%
df.Ingreso_Mensual.std()    # Desvaicion estandar Ingreso Mensual
# Out:
# 4707.956783097994

# %%
df['Ingreso_Mensual'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.countplot(x='Campo_Educación',data=df,order=df['Campo_Educación'].value_counts().index)
# con el metodo order=, ordeno los valores en forma ascendente
# Out:
# <Axes: xlabel='Campo_Educación', ylabel='count'>
